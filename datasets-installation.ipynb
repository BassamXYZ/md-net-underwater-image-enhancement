# %%
import kagglehub

# %%
path = kagglehub.dataset_download("larjeck/uieb-dataset-raw")
path = kagglehub.dataset_download("larjeck/uieb-dataset-reference")

# %%
path = kagglehub.dataset_download("noureldin199/lsui-large-scale-underwater-image-dataset")

# %%
# !curl -L -o /uieb-dataset-raw.zip\ https://www.kaggle.com/api/v1/datasets/download/larjeck/uieb-dataset-raw

# %%
# !curl -L -o /uieb-dataset-reference.zip\ https://www.kaggle.com/api/v1/datasets/download/larjeck/uieb-dataset-reference

# %%
# !curl -L -o /lsui-large-scale-underwater-image-dataset.zip\ https://www.kaggle.com/api/v1/datasets/download/noureldin199/lsui-large-scale-underwater-image-dataset
